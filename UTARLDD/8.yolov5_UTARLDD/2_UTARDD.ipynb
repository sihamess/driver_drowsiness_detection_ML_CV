# %% [markdown]
# # 1. Install and Import Dependencies

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
from IPython.display import Image  # for displaying images
import os
import random
import shutil
from sklearn.model_selection import train_test_split
import xml.etree.ElementTree as ET
from xml.dom import minidom
from tqdm import tqdm
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt
import uuid   # Unique identifier
import os
import time

random.seed(108)

# %%
#cd "/content/drive/MyDrive/drowiness_YawDD/yolov5_yawDD"
# !cd "/content/drive/MyDrive/drowsiness_yolo/8.yolov5_UTARLDD"

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# # 4. Train from scratch

# %%
t1=time.time()

# !python "/content/drive/MyDrive/drowsiness_yolo/8.yolov5_UTARLDD/train.py" --img 640 --batch 16 --epochs 50 --data "/content/drive/MyDrive/drowsiness_yolo/8.yolov5_UTARLDD/dataset.yaml" --weights yolov5s.pt --cache

t2= time.time()
temps_execution = t2 - t1
print(f"Le temps d'exécution est de {temps_execution} secondes.")
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#       24/49      4.01G    0.01748   0.006548  0.0008992         41        640:  80% 76/95 [00:09<00:02,  7.70it/s]/content/drive/MyDrive/drowsiness_yolo/8.yolov5_UTARLDD/train.py:309: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/49      4.01G    0.01748   0.006567  0.0008953         43        640:  81% 77/95 [00:10<00:02,  7.75it/s]/content/drive/MyDrive/drowsiness_yolo/8.yolov5_UTARLDD/train.py:309: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %% [markdown]
# # ***************************************************************************

# %% [markdown]
# # 5. Inference

# %%
#model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/drive/MyDrive/drowiness_YawDD/yolov5_yawDD/runs/train/exp4/weights/best.pt', force_reload=True)
model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/drive/MyDrive/drowsiness_yolo/8.yolov5_UTARLDD/runs/train/exp/weights/best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2024-12-28 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
t3=time.time()
#!python detect.py --source /content/drive/MyDrive/paper 3 siham/data/data1_yolov5/images/test  --weights /content/drive/MyDrive/paper 3 siham/data1_notebooks/1.yolov5/runs/train/exp4/weights/best.pt --conf 0.25 --name test_prediction
# !python "/content/drive/MyDrive/drowsiness_yolo/8.yolov5_UTARLDD/detect.py" --source "/content/drive/MyDrive/drowsiness_yolo/UTARLDD_yolo/images/test"  --weights "/content/drive/MyDrive/drowsiness_yolo/8.yolov5_UTARLDD/runs/train/exp/weights/best.pt" --conf 0.25 --name test_prediction

t4= time.time()
temps_execution = t4 - t3
print(f"Le temps d'exécution est de {temps_execution} secondes.")
# Out:
# detect: weights=['/content/drive/MyDrive/drowsiness_yolo/8.yolov5_UTARLDD/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/drowsiness_yolo/UTARLDD_yolo/images/test, data=drive/MyDrive/drowsiness_yolo/8.yolov5_UTARLDD/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=drive/MyDrive/drowsiness_yolo/8.yolov5_UTARLDD/runs/detect, name=test_prediction, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1979-12-31 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
#
# ...

# %% [markdown]
# #Computing the mAP on the test dataset

# %%
t5=time.time()
#!python val.py --weights  /content/drive/MyDrive/paper 3 siham/data1_notebooks/1.yolov5/runs/train/exp/weights/best.pt --data dataset_v2.yaml --task test
# !python '/content/drive/MyDrive/drowsiness_yolo/8.yolov5_UTARLDD/val.py' --weights  "/content/drive/MyDrive/drowsiness_yolo/8.yolov5_UTARLDD/runs/train/exp/weights/best.pt" --data "/content/drive/MyDrive/drowsiness_yolo/8.yolov5_UTARLDD/dataset.yaml" --task test

t6= time.time()
temps_execution = t6 - t5
print(f"Le temps d'exécution est de {temps_execution} secondes.")
# Out:
# val: data=/content/drive/MyDrive/drowsiness_yolo/8.yolov5_UTARLDD/dataset.yaml, weights=['/content/drive/MyDrive/drowsiness_yolo/8.yolov5_UTARLDD/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=drive/MyDrive/drowsiness_yolo/8.yolov5_UTARLDD/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 1979-12-31 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
#
# ...
