# %% [markdown]
# # 1. Install and Import Dependencies

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
from IPython.display import Image  # for displaying images
import os
import random
import shutil
from sklearn.model_selection import train_test_split
import xml.etree.ElementTree as ET
from xml.dom import minidom
from tqdm import tqdm
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt
import uuid   # Unique identifier
import os
import time

random.seed(108)

# %%
# !cd  "/content/drive/MyDrive/drowsiness_yolo/10.yolov5_nthuddd"
#!cd "/content/drive/MyDrive/drowiness_YawDD/10.yolov5_nthuddd"

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# # 4. Train from scratch

# %%
t1=time.time()

# !python "/content/drive/MyDrive/drowsiness_yolo/10.yolov5_nthuddd/train.py" --img 640 --batch 16 --epochs 50 --data "/content/drive/MyDrive/drowsiness_yolo/10.yolov5_nthuddd/dataset.yaml" --weights yolov5s.pt --cache

t2= time.time()
temps_execution = t2 - t1
print(f"Le temps d'exécution est de {temps_execution} secondes.")
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#       24/49      4.02G    0.01207   0.005573    0.00559         34        640:  80% 76/95 [00:25<00:05,  3.19it/s]/content/drive/MyDrive/drowsiness_yolo/10.yolov5_nthuddd/train.py:309: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/49      4.02G    0.01249   0.005575   0.005762         38        640:  81% 77/95 [00:25<00:05,  3.01it/s]/content/drive/MyDrive/drowsiness_yolo/10.yolov5_nthuddd/train.py:309: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %% [markdown]
# # ***************************************************************************

# %% [markdown]
# # 5. Inference

# %%
#model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/drive/MyDrive/drowiness_YawDD/yolov5_yawDD/runs/train/exp4/weights/best.pt', force_reload=True)
model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/drive/MyDrive/drowsiness_yolo/10.yolov5_nthuddd/runs/train/exp15/weights/best.pt', force_reload=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:330: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# ...

# %%
t3=time.time()
# !python /content/drive/MyDrive/drowiness_YawDD/10.yolov5_nthuddd/detect.py --source /content/drive/MyDrive/drowiness_YawDD/nthuddd_yolo/images/test  --weights /content/drive/MyDrive/drowiness_YawDD/10.yolov5_nthuddd/runs/train/exp5/weights/best.pt --conf 0.25 --name test_prediction
#!python "/content/drive/MyDrive/drowsiness_yolo/10.yolov5_nthuddd/runs/train/exp15/weights/best.pt" --conf 0.25 --name test_prediction

t4= time.time()
temps_execution = t4 - t3
print(f"Le temps d'exécution est de {temps_execution} secondes.")
# Out:
# python3: can't open file '/content/drive/MyDrive/drowiness_YawDD/10.yolov5_nthuddd/detect.py': [Errno 2] No such file or directory
# Le temps d'exécution est de 0.128004789352417 secondes.

# %% [markdown]
# #Computing the mAP on the test dataset

# %%
t5=time.time()
# !python /content/drive/MyDrive/drowsiness_yolo/10.yolov5_nthuddd/val.py --weights  /content/drive/MyDrive/drowsiness_yolo/10.yolov5_nthuddd/runs/train/exp15/weights/best.pt --data /content/drive/MyDrive/drowsiness_yolo/10.yolov5_nthuddd/dataset.yaml --task test
#!python '/content/drive/MyDrive/drowsiness_yolo/10.yolov5_nthuddd/val.py' --weights  "/content/drive/MyDrive/drowsiness_yolo/10.yolov5_nthuddd/dataset.yaml" --task test

t6= time.time()
temps_execution = t6 - t5
print(f"Le temps d'exécution est de {temps_execution} secondes.")
# Out:
# val: data=/content/drive/MyDrive/drowsiness_yolo/10.yolov5_nthuddd/dataset.yaml, weights=['/content/drive/MyDrive/drowsiness_yolo/10.yolov5_nthuddd/runs/train/exp15/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=drive/MyDrive/drowsiness_yolo/10.yolov5_nthuddd/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 1979-12-31 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# ...
