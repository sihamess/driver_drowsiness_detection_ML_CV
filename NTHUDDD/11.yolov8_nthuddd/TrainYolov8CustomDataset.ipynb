# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#cd /content/gdrive/MyDrive/drowiness_YawDD/yolov8_yawdd
# %cd '/content/drive/MyDrive/drowsiness_yolo/11.yolov8_nthuddd'
# Out:
# /content/drive/MyDrive/drowsiness_yolo/11.yolov8_nthuddd

# %%
# !pwd
# Out:
# /content/drive/MyDrive/drowsiness_yolo/11.yolov8_nthuddd

# %%
ROOT_DIR = '/content/drive/MyDrive/drowsiness_yolo/11.yolov8_nthuddd'

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 904.3/904.3 kB 47.0 MB/s eta 0:00:00
# ...

# %%
# !ls "/content/drive/MyDrive/drowsiness_yolo/11.yolov8_nthuddd"
# Out:
# dataset.yaml  runs  TrainYolov8CustomDataset.ipynb  yolo11n.pt	yolov8n.pt

# %%
import os
import time
from ultralytics import YOLO

t3= time.time()
# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch
# Use the model
#results = model.train(data=os.path.join(ROOT_DIR, "dataset.yaml"), epochs=50)  # train the model
results = model.train(data='/content/drive/MyDrive/drowsiness_yolo/11.yolov8_nthuddd/dataset.yaml', epochs=50)  # train the model
t4= time.time()
temps_execution = t4 - t3
print(f"Le temps d'exécution est de {temps_execution} secondes.")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.55 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
metrics = model.val()
# Out:
# Ultralytics 8.3.55 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# val: Scanning /content/drive/MyDrive/drowsiness_yolo/updated_nthuddd_yolo/labels/val.cache... 434 images, 0 backgrounds, 0 corrupt: 100%|██████████| 434/434 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 28/28 [00:03<00:00,  7.94it/s]
#                    all        434        434      0.997      0.997      0.995      0.975
#                  awake        205        205          1      0.995      0.995      0.982
#                 drowsy        229        229      0.994          1      0.995      0.968
# Speed: 0.2ms preprocess, 1.3ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to runs/detect/val3

# %%
from ultralytics import YOLO

#model = YOLO("/content/gdrive/MyDrive/drowiness_YawDD/yolov8_yawdd/runs/detect/train/weights/best.pt")
model = YOLO("/content/drive/MyDrive/drowsiness_yolo/11.yolov8_nthuddd/runs/detect/train7/weights/best.pt")
path = "/content/drive/MyDrive/drowsiness_yolo/updated_nthuddd_yolo/images/test"

results = model.predict(source=path, show=False, save=True, save_txt=True, save_conf=True)
# Out:
# image 1/214 /content/drive/MyDrive/drowsiness_yolo/updated_nthuddd_yolo/images/test/1012.jpg: 480x640 1 awake, 57.8ms
# image 2/214 /content/drive/MyDrive/drowsiness_yolo/updated_nthuddd_yolo/images/test/1032.jpg: 480x640 1 awake, 7.6ms
# image 3/214 /content/drive/MyDrive/drowsiness_yolo/updated_nthuddd_yolo/images/test/1033.jpg: 480x640 1 awake, 7.8ms
# image 4/214 /content/drive/MyDrive/drowsiness_yolo/updated_nthuddd_yolo/images/test/1048.jpg: 480x640 1 awake, 9.7ms
# image 5/214 /content/drive/MyDrive/drowsiness_yolo/updated_nthuddd_yolo/images/test/1050.jpg: 480x640 1 awake, 8.3ms
# image 6/214 /content/drive/MyDrive/drowsiness_yolo/updated_nthuddd_yolo/images/test/1058.jpg: 480x640 1 awake, 7.6ms
# image 7/214 /content/drive/MyDrive/drowsiness_yolo/updated_nthuddd_yolo/images/test/1065.jpg: 480x640 1 awake, 8.1ms
# image 8/214 /content/drive/MyDrive/drowsiness_yolo/updated_nthuddd_yolo/images/test/1071.jpg: 480x640 1 awake, 8.2ms
# ...

# %%
import os
import time
from ultralytics import YOLO

# Specify the directory where your dataset.yaml is located and where the model weights are saved
dataset_path = '/content/drive/MyDrive/drowsiness_yolo/11.yolov8_nthuddd/dataset.yaml'
weights_path = '/content/drive/MyDrive/drowsiness_yolo/11.yolov8_nthuddd/runs/detect/train7/weights/best.pt'

# Load the trained model
model = YOLO(weights_path)  # Load model with trained weights

# Evaluate the model to get the confusion matrix
t7 = time.time()
results = model.val(data=dataset_path, split='test') # Validate the model on the test set

t8 = time.time()
temps_evaluation = t8 - t7
print(f"Le temps d'évaluation est de {temps_evaluation} secondes.")
# Out:
# Ultralytics 8.3.55 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# YOLOv8n summary (fused): 168 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/drowsiness_yolo/updated_nthuddd_yolo/labels/test.cache... 214 images, 0 backgrounds, 0 corrupt: 100%|██████████| 214/214 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 14/14 [00:01<00:00,  7.00it/s]
#                    all        214        214      0.999          1      0.995       0.98
#                  awake        100        100      0.999          1      0.995      0.983
#                 drowsy        114        114          1          1      0.995      0.976
# Speed: 0.2ms preprocess, 1.5ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs/detect/val2
# Le temps d'évaluation est de 5.3272645473480225 secondes.
